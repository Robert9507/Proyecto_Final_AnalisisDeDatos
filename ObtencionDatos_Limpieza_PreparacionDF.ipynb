# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # AppBrain

# %% [markdown]
# #### Fuente 1 (AppBrain): https://www.appbrain.com/stats/google-play-rankings#

# %% [markdown]
# ## Obtención de datos

# %%
appBrain = pd.read_csv("googleplaystore_Appbrain.csv")
appBrain
# Out:
#                                                 App_2       Category  \
# 0            Temu: Shop Like a Billionaire\n\nby Temu       Shopping
# 1                       TikTok\n\nby TikTok Pte. Ltd.         Social
# 2   Street Fighter: Duel\n\nby Crunchyroll Games, LLC   Role Playing
# 3   SHEIN-Fashion Shopping Online\n\nby Roadget Bu...       Shopping
# 4               WhatsApp Messenger\n\nby WhatsApp LLC  Communication
# ..                                                ...            ...
# 95                              Xfinity\n\nby Comcast   Productivity
# 96                      YouTube Kids\n\nby Google LLC  Entertainment
# 97             Chess - Play and Learn\n\nby Chess.com          Board
# 98                           Mob Control\n\nby VOODOO         Arcade
# 99               Storm Cleaner\n\nby Storm Clean Team          Tools
#
#     Suma de Rank Installs  Suma de Rating
# 0              1    10 M+              46
# 1              2     1 B+              44
# ...

# %% [markdown]
# #### Obtener información sobre el DataFrame

# %%
# Incluyendo el número de filas y columnas, el tipo de datos de cada columna, 
# la cantidad de valores no nulos y la cantidad de memoria utilizada.

# %%
# La función info() es especialmente útil cuando se trabaja con grandes conjuntos de datos y se necesita una forma rápida 
# de verificar la estructura y los tipos de datos en el DataFrame o la Serie. 

# También es útil para detectar valores faltantes o nulos que puedan afectar el análisis posterior de los datos.

# %%
appBrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App_2           100 non-null    object
#  1   Category        100 non-null    object
#  2   Suma de Rank    100 non-null    int64
#  3   Installs        100 non-null    object
#  4   Suma de Rating  100 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 4.0+ KB

# %% [markdown]
# #### Obtener estadísticas descriptivas del DataFrame.

# %%
## Al llamar a la función describe(), se generará un resumen estadístico que incluye:

# el recuento de valores, la media, la desviación estándar, los valores mínimo y máximo, 
# y los percentiles (25%, 50%, y 75%) de las columnas numéricas del DataFrame o la Serie.

# %%
appBrain.describe()
# Out:
#        Suma de Rank  Suma de Rating
# count    100.000000      100.000000
# mean      50.500000       43.240000
# std       29.011492        3.438111
# min        1.000000       32.000000
# 25%       25.750000       41.000000
# 50%       50.500000       44.000000
# 75%       75.250000       46.000000
# max      100.000000       49.000000

# %% [markdown]
# #### Verificar si hay valores nulos en el DataFrame

# %%
print(appBrain.isnull().values.any())
# Out:
# False

# %%
print(appBrain.isnull().sum())
# Out:
# App_2             0
# Category          0
# Suma de Rank      0
# Installs          0
# Suma de Rating    0
# dtype: int64

# %%
import seaborn as sns

#Visualizamos en el heatmap como se encuentran valores nulos
sns.heatmap(appBrain.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Limpieza de datos

# %%
# no es necesaria

# %% [markdown]
# ## Preparación del DataFrame

# %%
appBrain['App_2'] = appBrain['App_2'].str.replace('[^a-zA-Z0-9\s]+', '', regex=False)
appBrain
# Out:
#                                                 App_2       Category  \
# 0             Temu Shop Like a Billionaire\n\nby Temu       Shopping
# 1                         TikTok\n\nby TikTok Pte Ltd         Social
# 2     Street Fighter Duel\n\nby Crunchyroll Games LLC   Role Playing
# 3   SHEINFashion Shopping Online\n\nby Roadget Bus...       Shopping
# 4               WhatsApp Messenger\n\nby WhatsApp LLC  Communication
# ..                                                ...            ...
# 95                              Xfinity\n\nby Comcast   Productivity
# 96                      YouTube Kids\n\nby Google LLC  Entertainment
# 97               Chess  Play and Learn\n\nby Chesscom          Board
# 98                           Mob Control\n\nby VOODOO         Arcade
# 99               Storm Cleaner\n\nby Storm Clean Team          Tools
#
#     Suma de Rank Installs  Suma de Rating
# 0              1    10 M+              46
# 1              2     1 B+              44
# ...

# %%
import random

# Asegurarse de que los valores de la columna "Installs" sean de tipo string
appBrain['Installs'] = appBrain['Installs'].astype(str)

# Recorrer cada fila de la columna "Installs" y reemplazar el valor con un número entero aleatorio
for i, row in appBrain.iterrows():
    appBrain.at[i, 'Installs'] = random.randint(1, 10000000)

# Mostrar el DataFrame actualizado
appBrain
# Out:
#                                                 App_2       Category  \
# 0             Temu Shop Like a Billionaire\n\nby Temu       Shopping
# 1                         TikTok\n\nby TikTok Pte Ltd         Social
# 2     Street Fighter Duel\n\nby Crunchyroll Games LLC   Role Playing
# 3   SHEINFashion Shopping Online\n\nby Roadget Bus...       Shopping
# 4               WhatsApp Messenger\n\nby WhatsApp LLC  Communication
# ..                                                ...            ...
# 95                              Xfinity\n\nby Comcast   Productivity
# 96                      YouTube Kids\n\nby Google LLC  Entertainment
# 97               Chess  Play and Learn\n\nby Chesscom          Board
# 98                           Mob Control\n\nby VOODOO         Arcade
# 99               Storm Cleaner\n\nby Storm Clean Team          Tools
#
#     Suma de Rank Installs  Suma de Rating
# 0              1  7511146              46
# 1              2  5931769              44
# ...

# %% [markdown]
# #### Guardar el nuevo DataFrame a utilizar en BDD SQL

# %%
guardadoAppBrainFinal = appBrain.to_csv('AppBrain_SQL.csv')

# %%
appBrainFinal = pd.read_csv("AppBrain_SQL.csv", index_col=[0])
appBrainFinal
# Out:
#                                                 App_2       Category  \
# 0             Temu Shop Like a Billionaire\n\nby Temu       Shopping
# 1                         TikTok\n\nby TikTok Pte Ltd         Social
# 2     Street Fighter Duel\n\nby Crunchyroll Games LLC   Role Playing
# 3   SHEINFashion Shopping Online\n\nby Roadget Bus...       Shopping
# 4               WhatsApp Messenger\n\nby WhatsApp LLC  Communication
# ..                                                ...            ...
# 95                              Xfinity\n\nby Comcast   Productivity
# 96                      YouTube Kids\n\nby Google LLC  Entertainment
# 97               Chess  Play and Learn\n\nby Chesscom          Board
# 98                           Mob Control\n\nby VOODOO         Arcade
# 99               Storm Cleaner\n\nby Storm Clean Team          Tools
#
#     Suma de Rank  Installs  Suma de Rating
# 0              1   7511146              46
# 1              2   5931769              44
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
visual = appBrainFinal[:5].copy()
visual
# Out:
#                                                App_2       Category  \
# 0            Temu Shop Like a Billionaire\n\nby Temu       Shopping
# 1                        TikTok\n\nby TikTok Pte Ltd         Social
# 2    Street Fighter Duel\n\nby Crunchyroll Games LLC   Role Playing
# 3  SHEINFashion Shopping Online\n\nby Roadget Bus...       Shopping
# 4              WhatsApp Messenger\n\nby WhatsApp LLC  Communication
#
#    Suma de Rank  Installs  Suma de Rating
# 0             1   7511146              46
# 1             2   5931769              44
# 2             3   9091447              48
# 3             4   4751372              47
# 4             5   2450135              43

# %%
visual.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Kaggle

# %% [markdown]
# #### Fuente 2 (Kaggle): https://www.kaggle.com/datasets/lava18/google-play-store-apps?select=googleplaystore.csv

# %% [markdown]
# ## Obtención de datos

# %%
kaggle = pd.read_csv("Kaggle.csv")
kaggle
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# #### Obtener información sobre el DataFrame

# %%
kaggle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Verificar si hay valores nulos

# %%
print(kaggle.isnull().values.any())
# Out:
# True

# %%
print(kaggle.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
import seaborn as sns

#Visualizamos en el heatmap como se encuentran valores nulos
sns.heatmap(kaggle.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preparación del DataFrame

# %% [markdown]
# #### Eliminar registros

# %%
eliminarRegistrosKaggle = kaggle.drop(range(100,10841), axis=0)

# %% [markdown]
# #### Guardo el nuevo Dataset

# %%
guardadoRegistrosKaggle = eliminarRegistrosKaggle.to_csv('kaggle_eliminacion_registros.csv')

# %% [markdown]
# #### Leer el nuevo Dataset

# %%
NuevosRegistrosKaggle = pd.read_csv('kaggle_eliminacion_registros.csv', index_col=[0])
NuevosRegistrosKaggle
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# ..                                                ...                ...
# 95  All of the parking lot - National Park applica...  AUTO_AND_VEHICLES
# 96               Inquiry Fines and Debits of Vehicles  AUTO_AND_VEHICLES
# 97                                        Gas Station  AUTO_AND_VEHICLES
# 98                         Hush - Beauty for Everyone             BEAUTY
# 99                     ipsy: Makeup, Beauty, and Tips             BEAUTY
#
#     Rating  Reviews  Size     Installs  Type  Price Content Rating  \
# ...

# %% [markdown]
# #### Eliminar columnas

# %%
eliminarColumnasKaggle = NuevosRegistrosKaggle.drop(['Price', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver'], axis=1)

# %% [markdown]
# #### Guardar el nuevo Dataset

# %%
guardadoColumnaskaggle = eliminarColumnasKaggle.to_csv('kaggle_eliminacion_columnas.csv')

# %% [markdown]
# #### Leer el nuevo Dataset

# %%
nuevasColumnasKaggle = pd.read_csv('kaggle_eliminacion_columnas.csv', index_col=[0])
nuevasColumnasKaggle
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# ..                                                ...                ...
# 95  All of the parking lot - National Park applica...  AUTO_AND_VEHICLES
# 96               Inquiry Fines and Debits of Vehicles  AUTO_AND_VEHICLES
# 97                                        Gas Station  AUTO_AND_VEHICLES
# 98                         Hush - Beauty for Everyone             BEAUTY
# 99                     ipsy: Makeup, Beauty, and Tips             BEAUTY
#
#     Rating  Reviews  Size     Installs  Type Content Rating
# ...

# %% [markdown]
# #### Eliminacion de caracteres especiales y el tipo de campo

# %%
#Se elimina el "+" y "," en la columna installs

nuevasColumnasKaggle['Installs'] = nuevasColumnasKaggle['Installs'].str.rstrip('+')
nuevasColumnasKaggle['Installs'] = nuevasColumnasKaggle['Installs'].str.replace(',','')

#Se cambia la columna installs a tipo int para poder hacer operaciones con ella
nuevasColumnasKaggle['Installs'] = nuevasColumnasKaggle['Installs'].astype(int)

# %%
nuevasColumnasKaggle
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# ..                                                ...                ...
# 95  All of the parking lot - National Park applica...  AUTO_AND_VEHICLES
# 96               Inquiry Fines and Debits of Vehicles  AUTO_AND_VEHICLES
# 97                                        Gas Station  AUTO_AND_VEHICLES
# 98                         Hush - Beauty for Everyone             BEAUTY
# 99                     ipsy: Makeup, Beauty, and Tips             BEAUTY
#
#     Rating  Reviews  Size  Installs  Type Content Rating
# ...

# %% [markdown]
# #### Verificamos

# %%
#Verificamos los valores únicos que contiene la columna Installs para así poder generar valores de Reviews más coherentes
print(nuevasColumnasKaggle['Installs'].unique())
# Out:
# [   10000   500000  5000000 50000000   100000    50000  1000000 10000000
#      5000]

# %% [markdown]
# #### Guardar el nuevo DataFrame

# %%
guardadokaggleFinal = nuevasColumnasKaggle.to_csv('kaggle_eliminacion_caracteres_especiales.csv')

# %% [markdown]
# ## Limpieza de datos

# %%
kaggleFinal = pd.read_csv('kaggle_eliminacion_caracteres_especiales.csv')
kaggleFinal
# Out:
#     Unnamed: 0                                                App  \
# 0            0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1            1                                Coloring book moana
# 2            2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3            3                              Sketch - Draw & Paint
# 4            4              Pixel Draw - Number Art Coloring Book
# ..         ...                                                ...
# 95          95  All of the parking lot - National Park applica...
# 96          96               Inquiry Fines and Debits of Vehicles
# 97          97                                        Gas Station
# 98          98                         Hush - Beauty for Everyone
# 99          99                     ipsy: Makeup, Beauty, and Tips
#
#              Category  Rating  Reviews  Size  Installs  Type Content Rating
# 0      ART_AND_DESIGN     4.1      159   19M     10000  Free       Everyone
# ...

# %% [markdown]
# #### Verificar si hay valores nulos en el DataFrame

# %%
print(kaggleFinal.isnull().values.any())
# Out:
# True

# %%
print(kaggleFinal.isnull().sum())
# Out:
# Unnamed: 0        0
# App               0
# Category          0
# Rating            1
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Content Rating    0
# dtype: int64

# %%
import seaborn as sns

#Visualizamos en el heatmap como se encuentran valores nulos
sns.heatmap(kaggleFinal.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Eliminar valores nulo

# %%
# Eliminar las filas con valores nulos en el DataFrame
kaggleEliminarValoresNulos = kaggleFinal.dropna(axis=0, thresh=None)

# Eliminar las filas con al menos dos valores no nulos
# df = df.dropna(axis=0, thresh=2)

# %% [markdown]
# #### Guardar el nuevo DataFrame

# %%
guardadoKaggleNulos = kaggleEliminarValoresNulos.to_csv('kaggle_sin_valores_nulos.csv')

# %% [markdown]
# #### Leer el nuevo DataFrame

# %%
kaggleSinNulos = pd.read_csv('kaggle_sin_valores_nulos.csv', index_col=[0])
kaggleSinNulos
# Out:
#     Unnamed: 0                                                App  \
# 0            0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1            1                                Coloring book moana
# 2            2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3            3                              Sketch - Draw & Paint
# 4            4              Pixel Draw - Number Art Coloring Book
# ..         ...                                                ...
# 95          95  All of the parking lot - National Park applica...
# 96          96               Inquiry Fines and Debits of Vehicles
# 97          97                                        Gas Station
# 98          98                         Hush - Beauty for Everyone
# 99          99                     ipsy: Makeup, Beauty, and Tips
#
#              Category  Rating  Reviews  Size  Installs  Type Content Rating
# 0      ART_AND_DESIGN     4.1      159   19M     10000  Free       Everyone
# ...

# %% [markdown]
# #### Cambio el nombre de la columna "Content Rating"

# %%
kaggleCo = kaggleSinNulos.rename(columns={'Content Rating': 'Content_Rating'})

# %%
kaggleCo
# Out:
#     Unnamed: 0                                                App  \
# 0            0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1            1                                Coloring book moana
# 2            2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3            3                              Sketch - Draw & Paint
# 4            4              Pixel Draw - Number Art Coloring Book
# ..         ...                                                ...
# 95          95  All of the parking lot - National Park applica...
# 96          96               Inquiry Fines and Debits of Vehicles
# 97          97                                        Gas Station
# 98          98                         Hush - Beauty for Everyone
# 99          99                     ipsy: Makeup, Beauty, and Tips
#
#              Category  Rating  Reviews  Size  Installs  Type Content_Rating
# 0      ART_AND_DESIGN     4.1      159   19M     10000  Free       Everyone
# ...

# %% [markdown]
# #### Guardar el nuevo DataFrame a utilizar en BDD SQL

# %%
guardadoKaggelFinal = kaggleCo.to_csv('Kaggle_SQL.csv')

# %%
KaggelFinal = pd.read_csv('Kaggle_SQL.csv', index_col=[0])
KaggelFinal
# Out:
#     Unnamed: 0                                                App  \
# 0            0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1            1                                Coloring book moana
# 2            2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3            3                              Sketch - Draw & Paint
# 4            4              Pixel Draw - Number Art Coloring Book
# ..         ...                                                ...
# 95          95  All of the parking lot - National Park applica...
# 96          96               Inquiry Fines and Debits of Vehicles
# 97          97                                        Gas Station
# 98          98                         Hush - Beauty for Everyone
# 99          99                     ipsy: Makeup, Beauty, and Tips
#
#              Category  Rating  Reviews  Size  Installs  Type Content_Rating
# 0      ART_AND_DESIGN     4.1      159   19M     10000  Free       Everyone
# ...

# %% [markdown]
# #### Visualización de gráficos

# %%
df_group = KaggelFinal.groupby(['Category'])['Rating'].count().reset_index()
df_group.columns = ['Category', 'Rating']

# %%
plt.pie(df_group['Rating'],labels=df_group['Category'],autopct='%.2f')
plt.title('% en categorías')

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,7))

plt.violinplot(KaggelFinal['Reviews'], showmedians=True)
plt.xticks([1], ['Reviews'])
plt.show()

# %% [markdown]
# # Data and sons

# %% [markdown]
# #### Fuente 3 (Data and son): https://www.dataandsons.com/categories/markets/google-playstore-app-data

# %%
dataAndSons = pd.read_csv("googleplaystore_Dataandsons.csv")
dataAndSons
# Out:
#     Ad Supported                                             App Id  \
# 0           True                       air.me.kupina.EnBuscaDeJesus
# 1           True                                  algerie.auto.news
# 2           True                              androbros.com.wordfit
# 3          False                      au.com.forward.pfodDesignerV2
# 4           True                           chumob.ghost.photo.maker
# 5           True                            com.allocine.androidapp
# 6           True                    com.andromo.dev614880.app882120
# 7           True                      com.ape.halloween.slotmachine
# 8          False                                     com.app.shiraa
# 9          False                        com.appcapsule.ac3200368001
# 10          True                                    com.cresh.cmdys
# 11          True                           com.elum.doorlock.screen
# 12          True  com.english_spanish_phrases_offline.jovokrneta...
# ...

# %% [markdown]
# #### Obtener información sobre el DataFrame

# %%
dataAndSons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Ad Supported              50 non-null     bool
#  1   App Id                    50 non-null     object
#  2   App Name                  50 non-null     object
#  3   Category                  50 non-null     object
#  4   Content Rating            50 non-null     object
#  5   Currency                  50 non-null     object
#  6   Developer Email           50 non-null     object
#  7   Developer Id              50 non-null     object
#  8   Developer Website         37 non-null     object
#  9   Editors Choice            50 non-null     bool
#  10  Free                      50 non-null     bool
#  11  In App Purchases          50 non-null     bool
#  12  Installs                  50 non-null     object
#  13  Suma de Last Updated      50 non-null     int64
# ...

# %% [markdown]
# #### Verificar si hay valores nulos

# %%
print(dataAndSons.isnull().values.any())
# Out:
# True

# %%
print(dataAndSons.isnull().sum())
# Out:
# Ad Supported                 0
# App Id                       0
# App Name                     0
# Category                     0
# Content Rating               0
# Currency                     0
# Developer Email              0
# Developer Id                 0
# Developer Website           13
# Editors Choice               0
# Free                         0
# In App Purchases             0
# Installs                     0
# Suma de Last Updated         0
# Suma de Maximum Installs     0
# Minimum Android              0
# Suma de Minimum Installs     0
# Suma de Price                0
# Privacy Policy               8
# Suma de Rating               0
# Suma de Rating Count         0
# Año                          2
# Trimestre                    2
# Mes                          2
# Día                          2
# Size                         0
# dtype: int64

# %%
import seaborn as sns

#Visualizamos en el heatmap como se encuentran valores nulos
sns.heatmap(dataAndSons.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preparación del DataFrame

# %% [markdown]
# #### Eliminar columnas

# %%
eliminarColumnasDataAndSons = dataAndSons.drop(['Ad Supported', 
                                                'App Id', 
                                                'Currency', 
                                                'Developer Email', 
                                                'Developer Id',
                                                'Developer Website',
                                                'Editors Choice',
                                                'Free',
                                                'In App Purchases',
                                                'Suma de Last Updated',
                                                'Minimum Android',
                                                'Suma de Minimum Installs',
                                                'Suma de Price',
                                                'Privacy Policy',
                                                'Año',
                                                'Trimestre',
                                                'Mes',
                                                'Día',
                                                'Size'], axis=1)

# %% [markdown]
# #### Guardar el nuevo Dataset

# %%
guardadoColumnasDataAndSons = eliminarColumnasDataAndSons.to_csv('DataAndSons_eliminacion_columnas.csv')

# %% [markdown]
# #### Leer el nuevo DataFrame

# %%
nuevasColumnasDataAndSons = pd.read_csv('DataAndSons_eliminacion_columnas.csv', index_col=[0])
nuevasColumnasDataAndSons
# Out:
#                                              App Name           Category  \
# 0                             A Journey Towards Jesus             Trivia
# 1                                  AlgÃ©rie auto news   News & Magazines
# 2                               Crossword : Word Fill               Word
# 3                         pfodDesigner V3 for pfodApp      Communication
# 4         Ghost Photo Maker - Used with ghost sticker        Photography
# 5                                            AlloCine      Entertainment
# 6                        Turkey recipes for Christmas       Food & Drink
# 7                              Halloween Slot Machine             Casino
# 8                                          Ash-shiraa   News & Magazines
# 9                                           å¿è·¯è»          Lifestyle
# 10                      Computer Crash course 45 Days          Education
# 11       Door Screen Lock - Secure Screen Locker 2020    Personalization
# ...

# %% [markdown]
# #### Eliminacion de caracteres especiales y el tipo de campo

# %%
#Se elimina el "+" y "," en la columna Installs

nuevasColumnasDataAndSons['Installs'] = nuevasColumnasDataAndSons['Installs'].str.rstrip('+')
nuevasColumnasDataAndSons['Installs'] = nuevasColumnasDataAndSons['Installs'].str.replace(',','')

#Se cambia la columna installs a tipo int para poder hacer operaciones con ella
nuevasColumnasDataAndSons['Installs'] = nuevasColumnasDataAndSons['Installs'].astype(int)

# %%
nuevasColumnasDataAndSons
# Out:
#                                              App Name           Category  \
# 0                             A Journey Towards Jesus             Trivia
# 1                                  AlgÃ©rie auto news   News & Magazines
# 2                               Crossword : Word Fill               Word
# 3                         pfodDesigner V3 for pfodApp      Communication
# 4         Ghost Photo Maker - Used with ghost sticker        Photography
# 5                                            AlloCine      Entertainment
# 6                        Turkey recipes for Christmas       Food & Drink
# 7                              Halloween Slot Machine             Casino
# 8                                          Ash-shiraa   News & Magazines
# 9                                           å¿è·¯è»          Lifestyle
# 10                      Computer Crash course 45 Days          Education
# 11       Door Screen Lock - Secure Screen Locker 2020    Personalization
# ...

# %% [markdown]
# #### Verificar si hay valores nulos

# %%
print(nuevasColumnasDataAndSons.isnull().values.any())
# Out:
# False

# %%
print(nuevasColumnasDataAndSons.isnull().sum())
# Out:
# App Name                    0
# Category                    0
# Content Rating              0
# Installs                    0
# Suma de Maximum Installs    0
# Suma de Rating              0
# Suma de Rating Count        0
# dtype: int64

# %% [markdown]
# #### Verificamos

# %%
#Verificamos los valores únicos que contiene la columna Installs para así poder generar valores de Reviews más coherentes
print(nuevasColumnasDataAndSons['Installs'].unique())
# Out:
# [ 1000000     5000   500000     1000  5000000       50      100      500
#     10000   100000        1    50000 10000000       10]

# %% [markdown]
# #### Guardar el nuevo DataFrame a utilizar en BDD SQL

# %%
guardadoDataAndSonsFinal = nuevasColumnasDataAndSons.to_csv('DataAndSons_SQL.csv')

# %%
DataAndSonsFinal = pd.read_csv('DataAndSons_SQL.csv', index_col=[0])
DataAndSonsFinal
# Out:
#                                              App Name           Category  \
# 0                             A Journey Towards Jesus             Trivia
# 1                                  AlgÃ©rie auto news   News & Magazines
# 2                               Crossword : Word Fill               Word
# 3                         pfodDesigner V3 for pfodApp      Communication
# 4         Ghost Photo Maker - Used with ghost sticker        Photography
# 5                                            AlloCine      Entertainment
# 6                        Turkey recipes for Christmas       Food & Drink
# 7                              Halloween Slot Machine             Casino
# 8                                          Ash-shiraa   News & Magazines
# 9                                           å¿è·¯è»          Lifestyle
# 10                      Computer Crash course 45 Days          Education
# 11       Door Screen Lock - Secure Screen Locker 2020    Personalization
# ...

# %%
#importar matpLotlib
import matplotlib.pyplot as plt

# %%
#gráfico de puntos utilizando matplotlib
plt.bar(DataAndSonsFinal['Content Rating' ], DataAndSonsFinal['Installs'])
plt.show()
