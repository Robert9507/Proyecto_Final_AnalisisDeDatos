# %% [markdown]
# # AppBrain

# %% [markdown]
# #### Fuente 1 (AppBrain): https://www.appbrain.com/stats/google-play-rankings#

# %%
import pandas as pd
pd.read_csv("googleplaystore_Appbrain.csv")
# Out:
#                                                 App_2       Category  \
# 0            Temu: Shop Like a Billionaire\n\nby Temu       Shopping
# 1                       TikTok\n\nby TikTok Pte. Ltd.         Social
# 2   Street Fighter: Duel\n\nby Crunchyroll Games, LLC   Role Playing
# 3   SHEIN-Fashion Shopping Online\n\nby Roadget Bu...       Shopping
# 4               WhatsApp Messenger\n\nby WhatsApp LLC  Communication
# ..                                                ...            ...
# 95                              Xfinity\n\nby Comcast   Productivity
# 96                      YouTube Kids\n\nby Google LLC  Entertainment
# 97             Chess - Play and Learn\n\nby Chess.com          Board
# 98                           Mob Control\n\nby VOODOO         Arcade
# 99               Storm Cleaner\n\nby Storm Clean Team          Tools
#
#     Suma de Rank Installs  Suma de Rating
# 0              1    10 M+              46
# 1              2     1 B+              44
# ...

# %% [markdown]
# # Kaggle

# %% [markdown]
# #### Fuente 2 (Kaggle): https://www.kaggle.com/datasets/lava18/google-play-store-apps?select=googleplaystore.csv

# %%
import pandas as pd
pd.read_csv("googleplaystore_Kaggle.csv")
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # Thewebminer

# %% [markdown]
# #### Fuente 3 (Thewebminer): https://thewebminer.com/android-google-play-apps

# %%
import pandas as pd
pd.read_csv("googleplaystore_Thewebminer.csv")
# Out:
#                                      id                           title  \
# 0                  air.com.Frosby.Qixel       Qixel : Pixel Art Painter
# 1    tr.com.mnk.nurettin.darbukadoumbek                 Darbuka Doumbek
# 2            com.mayimbe.crossymemo.app                     Crossy MeMo
# 3                       com.list.circle                            서클.두
# 4            com.counterpoint.kinlocate        dondeEsta Family Locator
# ..                                  ...                             ...
# 995    com.tiltangames.easterpuzzlelite  Easter Games for Kids: Puzzles
# 996             com.estudio503.tinmarin                       Tin Marín
# 997                   com.mocoga.pororo              Pororo Penguin Run
# 998            com.playtales.es.alacama       ¡A la cama! niños y niñas
# 999              com.jm.seabattlepirate               Sea Battle Pirate
#
#                        author      price  \
# 0              Frosby Studios  $1.49 Buy
# ...

# %% [markdown]
# # Data For seo

# %% [markdown]
# #### Fuente 4 (Data For seo): https://datasetsearch.research.google.com/search?query=mobile%20app&docid=L2cvMTFocmNjZHlrNw%3D%3D

# %%
import pandas as pd
pd.read_csv("googleplaystore_DataForseo.csv")
# Out:
#                           _id                                 keyword  \
# 0    640228b156a169452e68cdc2                            pizza sylmar
# 1    640228b156a169452e68cdc3                       pizza with capers
# 2    640228b156a169452e68cdc4                                    pksa
# 3    640228b156a169452e68cdc5  places that are open right now near me
# 4    640228b156a169452e68cdc6     places that sell hot wheels near me
# ..                        ...                                     ...
# 995  640228b156a169452e68d1a5                             rope master
# 996  640228b156a169452e68d1a6                 rose gold snapchat logo
# 997  640228b156a169452e68d1a7                   rose screen wallpaper
# 998  640228b156a169452e68d1a8                            rotunda ford
# 999  640228b156a169452e68d1a9                    roulette name picker
#
#      keyword_info.search_volume      keyword_info.time_update language  \
# ...

# %% [markdown]
# # Data and sons

# %% [markdown]
# #### Fuente 5 (Data and sons): https://www.dataandsons.com/categories/markets/google-playstore-app-data

# %%
import pandas as pd
pd.read_csv("googleplaystore_Dataandsons.csv")
# Out:
#                                               Column1  \
# 0   ã¯ã©ã·ã« - æçãã¬ã·ãåç»ã§ç°¡å...
# 1                           Allrecipes Dinner Spinner
# 2                                            App Name
# 3                                     Brands For Less
# 4                                         Chick-fil-A
# 5                   Cookpad - Create your own Recipes
# 6                                  Domino's Pizza USA
# 7                                   DoorDash - Driver
# 8                            DoorDash - Food Delivery
# 9                              DoorDash Order Manager
# 10                  Easy Healthy Recipes for free app
# 11  eBay - Buy, sell, and discover summer deals today
# 12     Fast Food Locator | Worldwide Fast Food Finder
# 13                                       Food Planner
# 14          foodpanda - Local Food & Grocery Delivery
# 15                                        FreshDirect
# ...
